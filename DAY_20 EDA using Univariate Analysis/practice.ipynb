# %%
import pandas as pd

# %%
df = pd.read_csv('employees.csv')

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#               Salary      Bonus %
# count    1000.000000  1000.000000
# mean    90662.181000    10.207555
# std     32923.693342     5.528481
# min     35013.000000     1.015000
# 25%     62613.000000     5.401750
# 50%     90428.000000     9.838500
# 75%    118740.250000    14.838000
# max    149908.000000    19.944000

# %%
df.isnull().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
df.isnull().mean()
# Out:
# First Name           0.067
# Gender               0.145
# Start Date           0.000
# Last Login Time      0.000
# Salary               0.000
# Bonus %              0.000
# Senior Management    0.067
# Team                 0.043
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.corr(numeric_only=True)
# Out:
#            Salary   Bonus %
# Salary   1.000000 -0.036381
# Bonus % -0.036381  1.000000

# %%
import seaborn as sns

# %%
sns.countplot(df['Team'])
# Out:
# <Axes: xlabel='count', ylabel='Team'>

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Salary'],bins=20)
# Out:
# (array([49., 61., 63., 34., 55., 53., 51., 42., 62., 53., 53., 52., 48.,
#         55., 37., 57., 41., 43., 47., 44.]),
#  array([ 35013.  ,  40757.75,  46502.5 ,  52247.25,  57992.  ,  63736.75,
#          69481.5 ,  75226.25,  80971.  ,  86715.75,  92460.5 ,  98205.25,
#         103950.  , 109694.75, 115439.5 , 121184.25, 126929.  , 132673.75,
#         138418.5 , 144163.25, 149908.  ]),
#  <BarContainer object of 20 artists>)

# %%
sns.histplot(df['Salary'],kde=True,bins=20)
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
sns.boxplot(df['Salary'])
# Out:
# <Axes: ylabel='Salary'>
