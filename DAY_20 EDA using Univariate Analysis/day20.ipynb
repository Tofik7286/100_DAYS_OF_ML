# %%
import pandas as pd

# %%
df = pd.read_csv('employees.csv')

# %%
df.shape

# %%
df.sample(5)

# %%
df.info()

# %%
df.describe()

# %%
df.isnull().sum()

# %%
df.duplicated()

# %%
df.corr(numeric_only=True)

# %% [markdown]
# ### UNIVARIATE EDA

# %% [markdown]
# #### categorical data

# %%
#1. count plot

import seaborn as sns

# %%
sns.countplot(df['Team'])

# %%
import matplotlib.pyplot as plt

# %%
# df['Team'].isnull().sum()
df['Team'].dropna()

# %%
df['Team'].isnull().sum()

# %%
df

# %%
df['Team'].value_counts().plot(kind='pie',autopct='%1.1f%%')

# %%
## numerical data EDA

df.head()

# %%
plt.hist(df['Salary'],bins=20)

# %%
# 2 displot
sns.displot(df['Bonus %'],kde=True)
df.head()

# %%
sns.boxplot(df['Salary'])

# %%
df.head()
