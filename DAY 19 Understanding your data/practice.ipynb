# %%
import pandas as pd

# %%
df = pd.read_csv('clean_dataset.csv')

# %%
df.shape

# %%
df.sample(10)

# %%
df.isnull().sum()

# %%
df.info()

# %%
df.describe()

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 685    False
# 686    False
# 687    False
# 688    False
# 689    False
# Length: 690, dtype: bool

# %%
df.corr(numeric_only=True)['Approved']
# Out:
# Gender           -0.028934
# Age               0.164086
# Debt              0.206294
# Married           0.180583
# BankCustomer      0.188964
# YearsEmployed     0.322475
# PriorDefault      0.720407
# Employed          0.458301
# CreditScore       0.406410
# DriversLicense    0.031625
# ZipCode          -0.099598
# Income            0.175657
# Approved          1.000000
# Name: Approved, dtype: float64
