# %%
import pandas as pd 
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv('pokemon_data.csv')

# %%
df.sample(5)
# Out:
#        #     Name    Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 361  330   Flygon    Ground  Dragon  80     100       80       80       80
# 240  222  Corsola     Water    Rock  55      55       85       65       85
# 138  128   Tauros    Normal     NaN  75     100       95       40       70
# 638  577  Solosis   Psychic     NaN  45      30       40      105       50
# 599  539     Sawk  Fighting     NaN  75     125       75       30       75
#
#      Speed  Generation  Legendary
# 361    100           3      False
# 240     35           2      False
# 138    110           1      False
# 638     20           5      False
# 599     85           5      False

# %%
prof = ProfileReport(df)
prof.to_file(output_file='report.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 12/12 [00:00<00:00, 288.74it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
