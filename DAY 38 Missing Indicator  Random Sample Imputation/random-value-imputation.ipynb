# %%
# random value imputation 
- This technique can be applied on both numerical and categorical data.
- It replace missing values with random values from the same distribution as the observed data.
- This method can help to preserve the overall distribution of the data and can be useful when the missing data is not missing completely at random (MCAR).

# %%
# automatically-select-imputer-parameters

- In this technique we use GridSearchCV to automatically select the best parameters for the imputer.
- We can use this technique for both numerical and categorical data.
