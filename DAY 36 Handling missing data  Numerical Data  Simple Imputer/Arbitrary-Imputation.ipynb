# %%
# we fill the missing values with any number in Arbitrary value imputation. We can use any number which is not present in the data. It is a simple imputation technique.

# We use this technique more in categorical data where we can use "missing" or "unknown" as the value to fill the missing values. In numerical data we can use -999 or any other number which is not present in the data.
