# %% [markdown]
# ### JSON

# %%
import pandas as pd

# %%
df = pd.read_json('train.json')
df.head()
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213       indian                [water, vegetable oil, wheat, salt]
# 4  13162       indian  [black pepper, shallots, cornflour, cayenne pe...

# %% [markdown]
# ##### Importing json from url

# %%
df = pd.read_json('https://v6.exchangerate-api.com/v6/485ebc10da1cfbb273f72a6e/latest/USD')
df.head()
# Out:
#       result                          documentation  \
# USD  success  https://www.exchangerate-api.com/docs
# AED  success  https://www.exchangerate-api.com/docs
# AFN  success  https://www.exchangerate-api.com/docs
# ALL  success  https://www.exchangerate-api.com/docs
# AMD  success  https://www.exchangerate-api.com/docs
#
#                                terms_of_use  time_last_update_unix  \
# USD  https://www.exchangerate-api.com/terms             1771632002
# AED  https://www.exchangerate-api.com/terms             1771632002
# AFN  https://www.exchangerate-api.com/terms             1771632002
# ALL  https://www.exchangerate-api.com/terms             1771632002
# AMD  https://www.exchangerate-api.com/terms             1771632002
#
#                 time_last_update_utc  time_next_update_unix  \
# USD  Sat, 21 Feb 2026 00:00:02 +0000             1771718402
# AED  Sat, 21 Feb 2026 00:00:02 +0000             1771718402
# AFN  Sat, 21 Feb 2026 00:00:02 +0000             1771718402
# ...

# %% [markdown]
# ### Working with SQL

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(
    host= 'localhost',
    user='root',
    password='',
    database='world'
)

# %%
df  = pd.read_sql_query('SELECT * FROM country WHERE Region = "Caribbean"',conn)
# Out:
# C:\Users\Mohammad Tofik\AppData\Local\Temp\ipykernel_19940\2788711081.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df  = pd.read_sql_query('SELECT * FROM country WHERE Region = "Caribbean"',conn)

# %%
df.head()
# Out:
#   Code                  Name      Continent     Region  SurfaceArea  \
# 0  ABW                 Aruba  North America  Caribbean        193.0
# 1  AIA              Anguilla  North America  Caribbean         96.0
# 2  ANT  Netherlands Antilles  North America  Caribbean        800.0
# 3  ATG   Antigua and Barbuda  North America  Caribbean        442.0
# 4  BHS               Bahamas  North America  Caribbean      13878.0
#
#    IndepYear  Population  LifeExpectancy     GNP  GNPOld  \
# 0        NaN      103000            78.4   828.0   793.0
# 1        NaN        8000            76.1    63.2     NaN
# 2        NaN      217000            74.7  1941.0     NaN
# 3     1981.0       68000            70.5   612.0   584.0
# 4     1973.0      307000            71.1  3527.0  3347.0
#
#               LocalName                                GovernmentForm  \
# 0                 Aruba  Nonmetropolitan Territory of The Netherlands
# ...
