# %% [markdown]
# # Working with JSON

# %%
import pandas as pd

# %%
pd.read_json('train.json')

# %% [markdown]
# ## we can also read json file with URL

# %%
pd.read_json('https://v6.exchangerate-api.com/v6/485ebc10da1cfbb273f72a6e/latest/USD')

# %% [markdown]
# ## download sql connector

# %%
# !pip install mysql.connector

# %%
import mysql.connector

# %%
conn  = mysql.connector.connect(host="localhost",user='root',password="",database='world')

# %%
pd.read_sql_query('SELECT * FROM city WHERE Population > 1800000',conn)
